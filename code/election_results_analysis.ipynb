# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Import and Formatting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
#set the plotting style
sns.set_style("whitegrid")

# Model preprocessing
from sklearn.preprocessing import StandardScaler

#Modelling
import statsmodels.formula.api as smf
import statsmodels.api as sm

# Model metrics and analysis
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from statsmodels.stats.anova import anova_lm

# Plotting tools
import plotly.offline as po
import plotly.graph_objs as pg

#Scikit for imputer tools
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jamilditter/election_results/refs/heads/main/data/Voting_Breakdown_By_Socioeconomic_and_Demographic_Factors.csv')

# %%
df["pop_18_24_per"] = df["Population 18-24"] / df["voting_age_pop"]
df["pop_25_44_per"] = df["Population 25-44"] / df["voting_age_pop"]
df["pop_45_64_per"] = df["Population 45-64"] / df["voting_age_pop"]
df["pop_65_per"] = df["Population 65+"] / df["voting_age_pop"]

# %%
df["bach_per"] = df["bach_per"]/100
df["unemployment_rate"] = df["unemployment_rate"]/100

# %% [markdown]
# ## Heatmaps

# %%
predictor_variables = ['unemployment_rate', 'median_income', 'med_age', 'bach_per', 'hs_per', 'voter_participation', 'pop_18_24_per', 'pop_25_44_per', 'pop_45_64_per', 'pop_65_per', 'voting_age_pop']

numerical_predictors = df[predictor_variables].select_dtypes(include='number').columns.to_list()

corr_matrix_dem = df[numerical_predictors+ ["dem_votes_per"]].corr()

plt.figure(figsize=(15,10))

sns.heatmap(corr_matrix_dem, vmax=1, vmin=-1, square=True, annot=True, cmap="viridis")

plt.tick_params(labelsize=12)

plt.show()

# %%
corr_matrix_rep = df[numerical_predictors+ ["rep_votes_per"]].corr()

plt.figure(figsize=(15,10))

sns.heatmap(corr_matrix_rep, vmax=1, vmin=-1, square=True, annot=True, cmap="viridis")

plt.tick_params(labelsize=12)

plt.show()

# %% [markdown]
# ## Pairplots

# %%
fig = sns.pairplot(
    data=df,
    vars=numerical_predictors + ['dem_votes_per'],
    kind="reg",
    plot_kws={"scatter_kws": {"alpha": 0.5, "color": "k", "s": 7},
    },
)

for ax in fig.axes.flat:
    ax.set_xlabel(ax.get_xlabel(), fontsize=8, rotation=30, ha='right')  # X-axis label size and rotation
    ax.set_ylabel(ax.get_ylabel(), fontsize=8)  # Y-axis label size

    # Rotate x-axis tick labels
    plt.setp(ax.get_xticklabels(), rotation=30, ha='right')

plt.show()

# %%
fig = sns.pairplot(
    data=df,
    vars=numerical_predictors + ['rep_votes_per'],
    kind="reg",
    plot_kws={"scatter_kws": {"alpha": 0.5, "color": "k", "s": 7},
    },
)

for ax in fig.axes.flat:
    ax.set_xlabel(ax.get_xlabel(), fontsize=8, rotation=30, ha='right')  # X-axis label size and rotation
    ax.set_ylabel(ax.get_ylabel(), fontsize=8)  # Y-axis label size

    # Rotate x-axis tick labels
    plt.setp(ax.get_xticklabels(), rotation=30, ha='right')

plt.show()

# %% [markdown]
# ## Boxplots

# %%
plt.figure(figsize=(15,3))

fractions = list(numerical_predictors)
fractions.remove('voting_age_pop')
fractions.remove('median_income')
fractions.remove('med_age')

sns.boxplot(data=df[fractions], color='k')

plt.ylabel('Proportion', fontsize=15)

plt.tick_params(labelsize=12)

plt.show()

# %%
plt.figure(figsize=(3,3))

sns.boxplot(data=df, y = 'median_income', color='k')

plt.ylabel('Median Income ($)', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(3,3))

sns.boxplot(data=df, y = 'voting_age_pop', color='k')

plt.ylabel('Voting Age Population', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(3,3))

sns.boxplot(data=df, y = 'med_age', color='k')

plt.ylabel('Median Age', fontsize=15)

plt.show()

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Single input models

# %% [markdown]
# ### Median Income Single Inputs

# %% [markdown]
# #### Democrat Median Income

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'median_income',
            y = 'dem_votes_per',
            color='blue',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Median income ($)', fontsize=16)
plt.ylabel('Percentage of Democratic Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_med_income = df.dropna(subset=['median_income'])

# %%
model_median_income = smf.ols(formula='dem_votes_per ~ median_income', data=df_med_income).fit()

# %%
print(model_median_income.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.168
# Model:                            OLS   Adj. R-squared:                  0.166
# Method:                 Least Squares   F-statistic:                     69.01
# Date:                Mon, 03 Nov 2025   Prob (F-statistic):           2.34e-15
# Time:                        18:38:25   Log-Likelihood:                 280.27
# No. Observations:                 343   AIC:                            -556.5
# Df Residuals:                     341   BIC:                            -548.9
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.1996      0.033      6.004      0.000       0.134       0.265
# median_income  3.653e-06    4.4e-07      8.307      0.000    2.79e-06    4.52e-06
# ==============================================================================
# Omnibus:                       39.823   Durbin-Watson:                   1.565
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              122.119
# Skew:                           0.488   Prob(JB):                     3.04e-27
# Kurtosis:                       5.756   Cond. No.                     4.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_hat = model_median_income.predict()

# %%
np.sqrt(mean_squared_error(df_med_income['dem_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.107)

# %%
mean_absolute_error(df_med_income['dem_votes_per'], y_hat)
# Out:
# 0.07664660060737633

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_median_income.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# #### Republican Median Income

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'median_income',
            y = 'rep_votes_per',
            color='red',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Median income ($)', fontsize=16)
plt.ylabel('Percentage of Republican Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
model_median_income = smf.ols(formula='rep_votes_per ~ median_income', data=df_med_income).fit()

# %%
print(model_median_income.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     89.49
# Date:                Mon, 03 Nov 2025   Prob (F-statistic):           5.20e-19
# Time:                        18:42:24   Log-Likelihood:                 290.36
# No. Observations:                 343   AIC:                            -576.7
# Df Residuals:                     341   BIC:                            -569.0
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.7938      0.032     24.586      0.000       0.730       0.857
# median_income -4.039e-06   4.27e-07     -9.460      0.000   -4.88e-06    -3.2e-06
# ==============================================================================
# Omnibus:                       59.582   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              143.335
# Skew:                          -0.851   Prob(JB):                     7.50e-32
# Kurtosis:                       5.670   Cond. No.                     4.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_hat = model_median_income.predict()

# %%
np.sqrt(mean_squared_error(df_med_income['rep_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.104)

# %%
mean_absolute_error(df_med_income['rep_votes_per'], y_hat)
# Out:
# 0.0751220363055787

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_median_income.resid, 'ko', mec='w')
plt.axhline(0, color='r', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Republican voters', fontsize=16)
plt.ylabel('Residual percentage of Republican voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ### Unemployment Rate Single Inputs

# %% [markdown]
# #### Democrat Unemployment Rate

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'unemployment_rate',
            y = 'dem_votes_per',
            color='blue',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Unemployment Rate (%)', fontsize=16)
plt.ylabel('Percentage of Democratic Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_dem_urate = df.dropna(subset=['unemployment_rate'])

# %%
model_dem_urate = smf.ols(formula='dem_votes_per ~ unemployment_rate', data=df_dem_urate).fit()

# %%
print(model_dem_urate.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     29.12
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):           1.25e-07
# Time:                        14:12:34   Log-Likelihood:                 273.05
# No. Observations:                 357   AIC:                            -542.1
# Df Residuals:                     355   BIC:                            -534.3
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.3807      0.018     21.176      0.000       0.345       0.416
# unemployment_rate     1.7099      0.317      5.396      0.000       1.087       2.333
# ==============================================================================
# Omnibus:                       41.623   Durbin-Watson:                   1.620
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.854
# Skew:                           0.672   Prob(JB):                     2.05e-17
# Kurtosis:                       4.833   Cond. No.                         53.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_dem_urate.predict()

# %%
np.sqrt(mean_squared_error(df_dem_urate['dem_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.113)

# %%
mean_absolute_error(df_dem_urate['dem_votes_per'], y_hat)
# Out:
# 0.08704922671445302

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_dem_urate.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# #### Republican Unemployment Rate

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'unemployment_rate',
            y = 'rep_votes_per',
            color='red',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Unemployment Rate (%)', fontsize=16)
plt.ylabel('Percentage of Republican Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_rep_urate = df.dropna(subset=['unemployment_rate'])

# %%
model_rep_urate = smf.ols(formula='rep_votes_per ~ unemployment_rate', data=df_unemployment_rate).fit()

# %%
print(model_rep_urate.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     10.57
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):            0.00126
# Time:                        14:17:54   Log-Likelihood:                 267.47
# No. Observations:                 357   AIC:                            -530.9
# Df Residuals:                     355   BIC:                            -523.2
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.5479      0.018     30.008      0.000       0.512       0.584
# unemployment_rate    -1.0463      0.322     -3.250      0.001      -1.679      -0.413
# ==============================================================================
# Omnibus:                       57.637   Durbin-Watson:                   1.728
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              100.668
# Skew:                          -0.924   Prob(JB):                     1.38e-22
# Kurtosis:                       4.830   Cond. No.                         53.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_rep_urate.predict()

# %%
np.sqrt(mean_squared_error(df_rep_urate['rep_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.114)

# %%
mean_absolute_error(df_dem_urate['rep_votes_per'], y_hat)
# Out:
# 0.08896018040441507

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_dem_urate.resid, 'ko', mec='w')
plt.axhline(0, color='r', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Republican voters', fontsize=16)
plt.ylabel('Residual percentage of Republican voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ### Voting Participation Rate Single Inputs

# %% [markdown]
# #### Democrat Voting Participation Rate

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'voter_participation',
            y = 'dem_votes_per',
            color='blue',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Voting Participation Rate (%)', fontsize=16)
plt.ylabel('Percentage of Democratic Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_dem_vrate = df.dropna(subset=['voter_participation'])

# %%
model_dem_vrate = smf.ols(formula='dem_votes_per ~ voter_participation', data=df_dem_vrate).fit()

# %%
print(model_dem_vrate.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     13.33
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):           0.000300
# Time:                        14:46:20   Log-Likelihood:                 265.56
# No. Observations:                 357   AIC:                            -527.1
# Df Residuals:                     355   BIC:                            -519.4
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.5579      0.024     22.998      0.000       0.510       0.606
# voter_participation    -0.1427      0.039     -3.652      0.000      -0.219      -0.066
# ==============================================================================
# Omnibus:                       45.188   Durbin-Watson:                   1.637
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.721
# Skew:                           0.713   Prob(JB):                     2.43e-19
# Kurtosis:                       4.931   Cond. No.                         8.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_dem_vrate.predict()

# %%
np.sqrt(mean_squared_error(df_dem_vrate['dem_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.115)

# %%
mean_absolute_error(df_dem_vrate['dem_votes_per'], y_hat)
# Out:
# 0.09034900975483703

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_dem_vrate.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# #### Republican Voting Participation Rate

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'voter_participation',
            y = 'rep_votes_per',
            color='red',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Voting Participation Rate (%)', fontsize=16)
plt.ylabel('Percentage of Democratic Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_rep_vrate = df.dropna(subset=['voter_participation'])

# %%
model_rep_vrate = smf.ols(formula='rep_votes_per ~ voter_participation', data=df_rep_vrate).fit()

# %%
print(model_rep_vrate.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     6.838
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):            0.00930
# Time:                        15:02:36   Log-Likelihood:                 265.64
# No. Observations:                 357   AIC:                            -527.3
# Df Residuals:                     355   BIC:                            -519.5
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.5533      0.024     22.816      0.000       0.506       0.601
# voter_participation    -0.1021      0.039     -2.615      0.009      -0.179      -0.025
# ==============================================================================
# Omnibus:                       61.334   Durbin-Watson:                   1.742
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.505
# Skew:                          -0.932   Prob(JB):                     1.85e-26
# Kurtosis:                       5.119   Cond. No.                         8.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_rep_vrate.predict()

# %%
np.sqrt(mean_squared_error(df_rep_vrate['rep_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.115)

# %%
mean_absolute_error(df_rep_vrate['rep_votes_per'], y_hat)
# Out:
# 0.08858218493498995

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_dem_vrate.resid, 'ko', mec='w')
plt.axhline(0, color='r', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Republican voters', fontsize=16)
plt.ylabel('Residual percentage of Republican voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ### Voting age 18-24 Single Inputs

# %% [markdown]
# #### Democrat Voting age 18-24 Single Inputs

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'pop_18_24_per',
            y = 'dem_votes_per',
            color='blue',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Voting 18-24 Population(Total)', fontsize=16)
plt.ylabel('Percentage of Democratic Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_dem_1824 = df.dropna(subset=['pop_18_24_per'])

# %%
model_dem_1824 = smf.ols(formula='dem_votes_per ~ pop_18_24_per', data=df_dem_1824).fit()

# %%
print(model_dem_1824.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     17.93
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):           2.92e-05
# Time:                        15:20:03   Log-Likelihood:                 267.78
# No. Observations:                 357   AIC:                            -531.6
# Df Residuals:                     355   BIC:                            -523.8
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.7050      0.055     12.743      0.000       0.596       0.814
# pop_18_24_per    -1.8223      0.430     -4.235      0.000      -2.669      -0.976
# ==============================================================================
# Omnibus:                       79.969   Durbin-Watson:                   1.627
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              268.884
# Skew:                           0.970   Prob(JB):                     4.10e-59
# Kurtosis:                       6.784   Cond. No.                         72.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_dem_1824.predict()

# %%
np.sqrt(mean_squared_error(df_dem_1824['dem_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.114)

# %%
mean_absolute_error(df_dem_1824['dem_votes_per'], y_hat)
# Out:
# 0.08313630368877806

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_dem_1824.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# #### Republican Voting age 18-24 Single Inputs

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'pop_18_24_per',
            y = 'rep_votes_per',
            color='red',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Voting 18-24 Population(Total)', fontsize=16)
plt.ylabel('Percentage of Republican Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_rep_1824 = df.dropna(subset=['pop_18_24_per'])

# %%
model_rep_1824 = smf.ols(formula='rep_votes_per ~ pop_18_24_per', data=df_rep_1824).fit()

# %%
print(model_rep_1824.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     22.31
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):           3.34e-06
# Time:                        15:28:11   Log-Likelihood:                 273.11
# No. Observations:                 357   AIC:                            -542.2
# Df Residuals:                     355   BIC:                            -534.5
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.2361      0.055      4.331      0.000       0.129       0.343
# pop_18_24_per     2.0025      0.424      4.724      0.000       1.169       2.836
# ==============================================================================
# Omnibus:                      101.212   Durbin-Watson:                   1.800
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              305.503
# Skew:                          -1.286   Prob(JB):                     4.58e-67
# Kurtosis:                       6.731   Cond. No.                         72.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_rep_1824.predict()

# %%
np.sqrt(mean_squared_error(df_rep_1824['rep_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.113)

# %%
mean_absolute_error(df_rep_1824['rep_votes_per'], y_hat)
# Out:
# 0.082919454254533

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_rep_1824.resid, 'ko', mec='w')
plt.axhline(0, color='r', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Republican voters', fontsize=16)
plt.ylabel('Residual percentage of Republican voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ### Voting Age 25-44 Single Inputs

# %% [markdown]
# #### Democrat Voting Age 25-44 Single Inputs

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'pop_25_44_per',
            y = 'dem_votes_per',
            color='blue',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Voting 25-44 Population(Total)', fontsize=16)
plt.ylabel('Percentage of Democrat Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_dem_2544 = df.dropna(subset=['pop_25_44_per'])

# %%
model_dem_2544 = smf.ols(formula='dem_votes_per ~ pop_25_44_per', data=df_dem_2544).fit()

# %%
print(model_dem_2544.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     8.496
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):            0.00379
# Time:                        15:54:23   Log-Likelihood:                 263.20
# No. Observations:                 357   AIC:                            -522.4
# Df Residuals:                     355   BIC:                            -514.7
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.2828      0.065      4.334      0.000       0.154       0.411
# pop_25_44_per     0.5358      0.184      2.915      0.004       0.174       0.897
# ==============================================================================
# Omnibus:                       20.767   Durbin-Watson:                   1.576
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.195
# Skew:                           0.444   Prob(JB):                     4.58e-07
# Kurtosis:                       4.084   Cond. No.                         33.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_dem_2544.predict()

# %%
np.sqrt(mean_squared_error(df_dem_2544['dem_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.116)

# %%
mean_absolute_error(df_dem_2544['dem_votes_per'], y_hat)
# Out:
# 0.09123381072066351

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_dem_2544.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'pop_25_44_per',
            y = 'rep_votes_per',
            color='red',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Voting 25-44 Population(Total)', fontsize=16)
plt.ylabel('Percentage of Republican Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_rep_2544 = df.dropna(subset=['pop_25_44_per'])

# %%
model_rep_2544 = smf.ols(formula='rep_votes_per ~ pop_25_44_per', data=df_rep_2544).fit()

# %%
print(model_rep_2544.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     6.443
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):             0.0116
# Time:                        16:01:23   Log-Likelihood:                 265.44
# No. Observations:                 357   AIC:                            -526.9
# Df Residuals:                     355   BIC:                            -519.1
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.6558      0.065     10.114      0.000       0.528       0.783
# pop_25_44_per    -0.4637      0.183     -2.538      0.012      -0.823      -0.104
# ==============================================================================
# Omnibus:                       36.575   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.160
# Skew:                          -0.731   Prob(JB):                     2.11e-11
# Kurtosis:                       4.080   Cond. No.                         33.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_rep_2544.predict()

# %%
np.sqrt(mean_squared_error(df_rep_2544['rep_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.115)

# %%
mean_absolute_error(df_rep_2544['rep_votes_per'], y_hat)
# Out:
# 0.09109091673429888

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_rep_2544.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ## Multiple Linear Regression Model

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                357 non-null    object
#  1   year                 357 non-null    int64
#  2   total_votes          357 non-null    int64
#  3   dem_votes            357 non-null    int64
#  4   rep_votes            357 non-null    int64
#  5   other_votes          348 non-null    float64
#  6   green_votes          83 non-null     float64
#  7   unemployment_rate    357 non-null    float64
#  8   median_income        343 non-null    float64
#  9   med_age              306 non-null    float64
#  10  bach_per             357 non-null    float64
#  11  hs_per               306 non-null    float64
#  12  voting_age_pop       357 non-null    int64
#  13  Population 18-24     357 non-null    int64
#  14  Population 25-44     357 non-null    int64
#  15  Population 45-64     357 non-null    int64
#  16  Population 65+       357 non-null    int64
#  17  dem_votes_per        357 non-null    float64
#  18  rep_votes_per        357 non-null    float64
#  19  other_votes_per      348 non-null    float64
#  20  green_votes_per      83 non-null     float64
#  21  voter_participation  357 non-null    float64
#  22  pop_18_24_per        357 non-null    float64
#  23  pop_25_44_per        357 non-null    float64
#  24  pop_45_64_per        357 non-null    float64
#  25  pop_65_per           357 non-null    float64
# dtypes: float64(16), int64(9), object(1)
# memory usage: 72.6+ KB

# %%
model_dem = smf.ols(
    formula='dem_votes_per ~ unemployment_rate + median_income + med_age + bach_per + hs_per + voting_age_pop + pop_18_24_per + pop_25_44_per + pop_45_64_per + pop_65_per + voter_participation',
    data=df).fit()

# %%
print(model_dem.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.433
# Model:                            OLS   Adj. R-squared:                  0.410
# Method:                 Least Squares   F-statistic:                     19.54
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):           4.72e-29
# Time:                        16:19:30   Log-Likelihood:                 305.46
# No. Observations:                 294   AIC:                            -586.9
# Df Residuals:                     282   BIC:                            -542.7
# Df Model:                          11
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             867.0048    269.064      3.222      0.001     337.377    1396.633
# unemployment_rate       2.3164      0.358      6.468      0.000       1.611       3.021
# median_income        4.684e-06   5.41e-07      8.652      0.000    3.62e-06    5.75e-06
# med_age                -0.0093      0.005     -1.927      0.055      -0.019       0.000
# bach_per              -83.2418     26.687     -3.119      0.002    -135.772     -30.711
# hs_per                 -0.3116      0.140     -2.218      0.027      -0.588      -0.035
# voting_age_pop       1.308e-09   1.11e-09      1.178      0.240   -8.77e-10    3.49e-09
# pop_18_24_per        -867.7046    269.090     -3.225      0.001   -1397.384    -338.025
# pop_25_44_per        -866.0604    269.090     -3.218      0.001   -1395.741    -336.380
# pop_45_64_per        -865.6525    269.182     -3.216      0.001   -1395.514    -335.791
# pop_65_per           -866.1854    269.021     -3.220      0.001   -1395.730    -336.641
# voter_participation    -0.0237      0.089     -0.266      0.790      -0.199       0.151
# ==============================================================================
# Omnibus:                       95.688   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              387.066
# Skew:                           1.326   Prob(JB):                     8.91e-85
# Kurtosis:                       7.957   Cond. No.                     8.30e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.3e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_hat = model_dem.predict()

# %%
plt.figure(figsize=(7, 7))

plt.plot(y_hat, model_dem.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %%
model_rep = smf.ols(
    formula='rep_votes_per ~ unemployment_rate + median_income + med_age + bach_per + hs_per + voting_age_pop + pop_18_24_per + pop_25_44_per + pop_45_64_per + pop_65_per + voter_participation',
    data=df).fit()

# %%
print(model_rep.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.401
# Model:                            OLS   Adj. R-squared:                  0.378
# Method:                 Least Squares   F-statistic:                     17.16
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):           6.98e-26
# Time:                        16:19:38   Log-Likelihood:                 299.10
# No. Observations:                 294   AIC:                            -574.2
# Df Residuals:                     282   BIC:                            -530.0
# Df Model:                          11
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept           -1005.1937    274.947     -3.656      0.000   -1546.403    -463.984
# unemployment_rate      -1.5696      0.366     -4.289      0.000      -2.290      -0.849
# median_income       -4.631e-06   5.53e-07     -8.372      0.000   -5.72e-06   -3.54e-06
# med_age                 0.0044      0.005      0.881      0.379      -0.005       0.014
# bach_per               89.7358     27.270      3.291      0.001      36.057     143.415
# hs_per                  0.4096      0.144      2.853      0.005       0.127       0.692
# voting_age_pop       -1.15e-09   1.13e-09     -1.014      0.312   -3.38e-09    1.08e-09
# pop_18_24_per        1006.9495    274.974      3.662      0.000     465.688    1548.211
# pop_25_44_per        1005.0894    274.974      3.655      0.000     463.827    1546.352
# pop_45_64_per        1005.1873    275.069      3.654      0.000     463.739    1546.635
# pop_65_per           1005.5369    274.904      3.658      0.000     464.413    1546.661
# voter_participation     0.0290      0.091      0.319      0.750      -0.150       0.208
# ==============================================================================
# Omnibus:                       93.648   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              342.885
# Skew:                          -1.333   Prob(JB):                     3.49e-75
# Kurtosis:                       7.569   Cond. No.                     8.30e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.3e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_hat = model_rep.predict()

# %%
plt.figure(figsize=(7, 7))

plt.plot(y_hat, model_rep.resid, 'ko', mec='w')
plt.axhline(0, color='r', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Republican voters', fontsize=16)
plt.ylabel('Residual percentage of Republican voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ### Reduced Model

# %%
model_dem_reduced = smf.ols(
    formula='dem_votes_per ~ unemployment_rate + median_income + pop_18_24_per + pop_25_44_per',
    data=df).fit()

# %%
print(model_dem_reduced.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.340
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     43.62
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):           1.66e-29
# Time:                        16:19:49   Log-Likelihood:                 320.04
# No. Observations:                 343   AIC:                            -630.1
# Df Residuals:                     338   BIC:                            -610.9
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -0.0304      0.078     -0.391      0.696      -0.183       0.123
# unemployment_rate     2.1069      0.285      7.397      0.000       1.547       2.667
# median_income      3.463e-06   4.26e-07      8.137      0.000    2.63e-06     4.3e-06
# pop_18_24_per        -1.3566      0.420     -3.233      0.001      -2.182      -0.531
# pop_25_44_per         0.8658      0.172      5.033      0.000       0.527       1.204
# ==============================================================================
# Omnibus:                       49.258   Durbin-Watson:                   1.591
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              136.589
# Skew:                           0.659   Prob(JB):                     2.19e-30
# Kurtosis:                       5.796   Cond. No.                     6.32e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.32e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_hat = model_dem_reduced.predict()

# %%
plt.figure(figsize=(5, 5))

plt.plot(y_hat, model_dem_reduced.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %%
mean_absolute_error(df['average_act'], model_reduced.predict())

# %%
mae_full = mean_absolute_error(df['average_act'], model.predict())
mae_reduced = mean_absolute_error(df['average_act'], model_reduced.predict())

r2_full = model.rsquared
r2_reduced = model_reduced.rsquared

pd.DataFrame({'Mean Absolute Error': [mae_full, mae_reduced],
              'R-squared': [r2_full, r2_reduced]},
             index=['full model', 'reduced model']).round(4)

# %% [markdown]
# ### Scaling

# %%
predictor_variables = ['rate_unemployment', 'percent_college', 'percent_lunch']

# %%
scaled_columns = [var + '_normalized' for var in predictor_variables]
print(scaled_columns)

# %%
scaler = StandardScaler().fit(df[predictor_variables])

# %%
df[scaled_columns] = scaler.transform(df[predictor_variables])

# %%
df[scaled_columns].agg(['mean','std']).round(3)

# %%
model_normalized = smf.ols(formula='average_act ~ rate_unemployment_normalized + percent_college_normalized + percent_lunch_normalized',data=df).fit()

# %%
print(model_normalized.summary())

# %%
mae_normalized = mean_absolute_error(df['average_act'], model_normalized.predict())
mae_reduced = mean_absolute_error(df['average_act'], model_reduced.predict())

r2_normalized = model_normalized.rsquared
r2_reduced = model_reduced.rsquared

pd.DataFrame({'Mean Absolute Error': [mae_normalized, mae_reduced],
              'R-squared': [r2_normalized, r2_reduced]},
             index=['normalized model', 'reduced model']).round(4)
