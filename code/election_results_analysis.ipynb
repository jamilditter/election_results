# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Import and Formatting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
#set the plotting style
sns.set_style("whitegrid")

# Model preprocessing
from sklearn.preprocessing import StandardScaler

#Modelling
import statsmodels.formula.api as smf
import statsmodels.api as sm

# Model metrics and analysis
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from statsmodels.stats.anova import anova_lm

# Plotting tools
import plotly.offline as po
import plotly.graph_objs as pg

#Scikit for imputer tools
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

#Scikit for random forest model
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import plot_tree

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jamilditter/election_results/refs/heads/main/data/Voting_Breakdown_By_Socioeconomic_and_Demographic_Factors.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                357 non-null    object
#  1   year                 357 non-null    int64
#  2   total_votes          357 non-null    int64
#  3   dem_votes            357 non-null    float64
#  4   rep_votes            357 non-null    float64
#  5   unemployment_rate    357 non-null    float64
#  6   median_income        357 non-null    int64
#  7   med_age              306 non-null    float64
#  8   bach_per             357 non-null    float64
#  9   voter_participation  357 non-null    float64
#  10  voting_age_pop       357 non-null    float64
#  11  Population 18-24     357 non-null    int64
#  12  Population 25-44     357 non-null    int64
#  13  Population 45-64     357 non-null    int64
#  14  Population 65+       357 non-null    int64
#  15  dem_votes_per        357 non-null    float64
#  16  rep_votes_per        357 non-null    float64
#  17  dem_win              357 non-null    bool
# dtypes: bool(1), float64(9), int64(7), object(1)
# memory usage: 47.9+ KB

# %%
df["pop_18_24_per"] = df["Population 18-24"] / df["voting_age_pop"]
df["pop_25_44_per"] = df["Population 25-44"] / df["voting_age_pop"]
df["pop_45_64_per"] = df["Population 45-64"] / df["voting_age_pop"]
df["pop_65_per"] = df["Population 65+"] / df["voting_age_pop"]

# %%
df["unemployment_rate"] = df["unemployment_rate"]/100
df["voter_participation"] = df["voter_participation"]/100

# %% [markdown]
# ## Heatmaps

# %%
predictor_variables = ['unemployment_rate', 'median_income', 'med_age', 'bach_per', 'voter_participation', 'pop_18_24_per', 'pop_25_44_per', 'pop_45_64_per', 'pop_65_per', 'voting_age_pop']

numerical_predictors = df[predictor_variables].select_dtypes(include='number').columns.to_list()

corr_matrix_dem = df[numerical_predictors+ ["dem_votes_per"]].corr()

plt.figure(figsize=(15,10))

sns.heatmap(corr_matrix_dem, vmax=1, vmin=-1, square=True, annot=True, cmap="viridis")

plt.tick_params(labelsize=12)

plt.show()

# %%
corr_matrix_rep = df[numerical_predictors+ ["rep_votes_per"]].corr()

plt.figure(figsize=(15,10))

sns.heatmap(corr_matrix_rep, vmax=1, vmin=-1, square=True, annot=True, cmap="viridis")

plt.tick_params(labelsize=12)

plt.show()

# %% [markdown]
# ## Pairplots

# %%
fig = sns.pairplot(
    data=df,
    vars=numerical_predictors + ['dem_votes_per'],
    kind="reg",
    plot_kws={"scatter_kws": {"alpha": 0.5, "color": "k", "s": 7},
    },
)

for ax in fig.axes.flat:
    ax.set_xlabel(ax.get_xlabel(), fontsize=8, rotation=30, ha='right')  # X-axis label size and rotation
    ax.set_ylabel(ax.get_ylabel(), fontsize=8)  # Y-axis label size

    # Rotate x-axis tick labels
    plt.setp(ax.get_xticklabels(), rotation=30, ha='right')

plt.show()

# %%
fig = sns.pairplot(
    data=df,
    vars=numerical_predictors + ['rep_votes_per'],
    kind="reg",
    plot_kws={"scatter_kws": {"alpha": 0.5, "color": "k", "s": 7},
    },
)

for ax in fig.axes.flat:
    ax.set_xlabel(ax.get_xlabel(), fontsize=8, rotation=30, ha='right')  # X-axis label size and rotation
    ax.set_ylabel(ax.get_ylabel(), fontsize=8)  # Y-axis label size

    # Rotate x-axis tick labels
    plt.setp(ax.get_xticklabels(), rotation=30, ha='right')

plt.show()

# %% [markdown]
# ## Boxplots

# %%
plt.figure(figsize=(15,3))

fractions = list(numerical_predictors)
fractions.remove('voting_age_pop')
fractions.remove('median_income')
fractions.remove('med_age')

sns.boxplot(data=df[fractions], color='k')

plt.ylabel('Proportion', fontsize=15)

plt.tick_params(labelsize=12)

plt.show()

# %%
plt.figure(figsize=(3,3))

sns.boxplot(data=df, y = 'median_income', color='k')

plt.ylabel('Median Income ($)', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(3,3))

sns.boxplot(data=df, y = 'voting_age_pop', color='k')

plt.ylabel('Voting Age Population', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(3,3))

sns.boxplot(data=df, y = 'med_age', color='k')

plt.ylabel('Median Age', fontsize=15)

plt.show()

# %% [markdown]
# # Modelling

# %% [markdown]
# # Random Forest Model

# %% [markdown]
# ## National Model

# %%
X = df[numerical_predictors]
y = df["dem_win"]

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)

forest_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=9,
    random_state=0
)

forest_model.fit(X_train, y_train)

y_pred = forest_model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8333333333333334

# %%
class_report = classification_report(y_test, y_pred, output_dict=True)
class_report_df = pd.DataFrame(class_report).transpose()

print(class_report_df)
# Out:
#               precision    recall  f1-score    support
# False          0.800000  0.888889  0.842105  36.000000
# True           0.875000  0.777778  0.823529  36.000000
# accuracy       0.833333  0.833333  0.833333   0.833333
# macro avg      0.837500  0.833333  0.832817  72.000000
# weighted avg   0.837500  0.833333  0.832817  72.000000

# %%
tree = forest_model.estimators_[0]

plt.figure(figsize=(25, 10))
plot_tree(
    tree,
    feature_names=X.columns,
    class_names=[str(c) for c in forest_model.classes_],
    filled=True,
    rounded=True,
    fontsize=10
)
plt.show()

# %% [markdown]
# ## Swing State Models

# %%
df_penn = df[df["state"] == "PENNSYLVANIA"]

X = df_penn[numerical_predictors]
y = df_penn["dem_win"]

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)

forest_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=5,
    random_state=0
)

forest_model.fit(X_train, y_train)

y_pred = forest_model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5

# %%
class_report = classification_report(y_test, y_pred, output_dict=True)
class_report_df = pd.DataFrame(class_report).transpose()

print(class_report_df)
# Out:
#               precision  recall  f1-score  support
# False              0.00     0.0  0.000000      1.0
# True               0.50     1.0  0.666667      1.0
# accuracy           0.50     0.5  0.500000      0.5
# macro avg          0.25     0.5  0.333333      2.0
# weighted avg       0.25     0.5  0.333333      2.0
# e:\Anaconda2\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# e:\Anaconda2\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# e:\Anaconda2\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
tree = forest_model.estimators_[0]

plt.figure(figsize=(20, 10))
plot_tree(
    tree,
    feature_names=X.columns,
    class_names=[str(c) for c in forest_model.classes_],
    filled=True,
    rounded=True,
    fontsize=10
)
plt.show()

# %%
swing_states = ["WISCONSIN", "PENNYSLVANIA", "OHIO", "MICHIGAN", "FLORIDA"]

df_swing = df[df["state"].isin(swing_states)]

X = df_swing[numerical_predictors]
y = df_swing["dem_win"]

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2
)

forest_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=5,
    random_state=2
)

forest_model.fit(X_train, y_train)

y_pred = forest_model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5

# %%
class_report = classification_report(y_test, y_pred, output_dict=True)
class_report_df = pd.DataFrame(class_report).transpose()

print(class_report_df)
# Out:
#               precision  recall  f1-score  support
# False               0.0   0.000  0.000000      2.0
# True                0.6   0.750  0.666667      4.0
# accuracy            0.5   0.500  0.500000      0.5
# macro avg           0.3   0.375  0.333333      6.0
# weighted avg        0.4   0.500  0.444444      6.0

# %%
tree = forest_model.estimators_[0]

plt.figure(figsize=(20, 10))
plot_tree(
    tree,
    feature_names=X.columns,
    class_names=[str(c) for c in forest_model.classes_],
    filled=True,
    rounded=True,
    fontsize=10
)
plt.show()

# %% [markdown]
# # Linear Regression Model

# %% [markdown]
# ## Single input models

# %% [markdown]
# ### Median Income Single Inputs

# %% [markdown]
# #### Democrat Median Income

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'median_income',
            y = 'dem_votes_per',
            color='blue',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Median income ($)', fontsize=16)
plt.ylabel('Percentage of Democratic Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_med_income = df.dropna(subset=['median_income'])

# %%
model_median_income = smf.ols(formula='dem_votes_per ~ median_income', data=df_med_income).fit()

# %%
print(model_median_income.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.170
# Method:                 Least Squares   F-statistic:                     73.93
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           2.63e-16
# Time:                        16:31:08   Log-Likelihood:                 292.75
# No. Observations:                 357   AIC:                            -581.5
# Df Residuals:                     355   BIC:                            -573.7
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.1965      0.033      6.035      0.000       0.132       0.261
# median_income  3.702e-06   4.31e-07      8.598      0.000    2.86e-06    4.55e-06
# ==============================================================================
# Omnibus:                       39.141   Durbin-Watson:                   1.550
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              116.059
# Skew:                           0.471   Prob(JB):                     6.28e-26
# Kurtosis:                       5.630   Cond. No.                     4.35e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.35e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_hat = model_median_income.predict()

# %%
np.sqrt(mean_squared_error(df_med_income['dem_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.107)

# %%
mean_absolute_error(df_med_income['dem_votes_per'], y_hat)
# Out:
# 0.07696970328884095

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_median_income.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# #### Republican Median Income

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'median_income',
            y = 'rep_votes_per',
            color='red',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Median income ($)', fontsize=16)
plt.ylabel('Percentage of Republican Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
model_median_income = smf.ols(formula='rep_votes_per ~ median_income', data=df_med_income).fit()

# %%
print(model_median_income.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     93.55
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           8.52e-20
# Time:                        16:31:08   Log-Likelihood:                 303.99
# No. Observations:                 357   AIC:                            -604.0
# Df Residuals:                     355   BIC:                            -596.2
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.7925      0.032     25.120      0.000       0.730       0.855
# median_income -4.036e-06   4.17e-07     -9.672      0.000   -4.86e-06   -3.22e-06
# ==============================================================================
# Omnibus:                       59.342   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              139.815
# Skew:                          -0.828   Prob(JB):                     4.36e-31
# Kurtosis:                       5.580   Cond. No.                     4.35e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.35e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_hat = model_median_income.predict()

# %%
np.sqrt(mean_squared_error(df_med_income['rep_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.103)

# %%
mean_absolute_error(df_med_income['rep_votes_per'], y_hat)
# Out:
# 0.07491077832906702

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_median_income.resid, 'ko', mec='w')
plt.axhline(0, color='r', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Republican voters', fontsize=16)
plt.ylabel('Residual percentage of Republican voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ### Unemployment Rate Single Inputs

# %% [markdown]
# #### Democrat Unemployment Rate

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'unemployment_rate',
            y = 'dem_votes_per',
            color='blue',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Unemployment Rate (%)', fontsize=16)
plt.ylabel('Percentage of Democratic Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_dem_urate = df.dropna(subset=['unemployment_rate'])

# %%
model_dem_urate = smf.ols(formula='dem_votes_per ~ unemployment_rate', data=df_dem_urate).fit()

# %%
print(model_dem_urate.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     29.12
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           1.25e-07
# Time:                        16:31:08   Log-Likelihood:                 273.05
# No. Observations:                 357   AIC:                            -542.1
# Df Residuals:                     355   BIC:                            -534.3
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.3807      0.018     21.176      0.000       0.345       0.416
# unemployment_rate     1.7099      0.317      5.396      0.000       1.087       2.333
# ==============================================================================
# Omnibus:                       41.623   Durbin-Watson:                   1.620
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.854
# Skew:                           0.672   Prob(JB):                     2.05e-17
# Kurtosis:                       4.833   Cond. No.                         53.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_dem_urate.predict()

# %%
np.sqrt(mean_squared_error(df_dem_urate['dem_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.113)

# %%
mean_absolute_error(df_dem_urate['dem_votes_per'], y_hat)
# Out:
# 0.08704922671790592

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_dem_urate.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# #### Republican Unemployment Rate

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'unemployment_rate',
            y = 'rep_votes_per',
            color='red',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Unemployment Rate (%)', fontsize=16)
plt.ylabel('Percentage of Republican Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_rep_urate = df.dropna(subset=['unemployment_rate'])

# %%
model_rep_urate = smf.ols(formula='rep_votes_per ~ unemployment_rate', data=df_rep_urate).fit()

# %%
print(model_rep_urate.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     10.57
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):            0.00126
# Time:                        16:31:09   Log-Likelihood:                 267.47
# No. Observations:                 357   AIC:                            -530.9
# Df Residuals:                     355   BIC:                            -523.2
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.5479      0.018     30.008      0.000       0.512       0.584
# unemployment_rate    -1.0463      0.322     -3.250      0.001      -1.679      -0.413
# ==============================================================================
# Omnibus:                       57.637   Durbin-Watson:                   1.728
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              100.668
# Skew:                          -0.924   Prob(JB):                     1.38e-22
# Kurtosis:                       4.830   Cond. No.                         53.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_rep_urate.predict()

# %%
np.sqrt(mean_squared_error(df_rep_urate['rep_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.114)

# %%
mean_absolute_error(df_dem_urate['rep_votes_per'], y_hat)
# Out:
# 0.08896018040039533

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_dem_urate.resid, 'ko', mec='w')
plt.axhline(0, color='r', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Republican voters', fontsize=16)
plt.ylabel('Residual percentage of Republican voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ### Voting Participation Rate Single Inputs

# %% [markdown]
# #### Democrat Voting Participation Rate

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'voter_participation',
            y = 'dem_votes_per',
            color='blue',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Voting Participation Rate (%)', fontsize=16)
plt.ylabel('Percentage of Democratic Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_dem_vrate = df.dropna(subset=['voter_participation'])

# %%
model_dem_vrate = smf.ols(formula='dem_votes_per ~ voter_participation', data=df_dem_vrate).fit()

# %%
print(model_dem_vrate.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.103
# Model:                            OLS   Adj. R-squared:                  0.101
# Method:                 Least Squares   F-statistic:                     40.79
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           5.33e-10
# Time:                        16:31:09   Log-Likelihood:                 278.39
# No. Observations:                 357   AIC:                            -552.8
# Df Residuals:                     355   BIC:                            -545.0
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.0654      0.064      1.023      0.307      -0.060       0.191
# voter_participation     0.6339      0.099      6.386      0.000       0.439       0.829
# ==============================================================================
# Omnibus:                       25.770   Durbin-Watson:                   1.598
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.342
# Skew:                           0.509   Prob(JB):                     4.72e-09
# Kurtosis:                       4.242   Cond. No.                         23.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_dem_vrate.predict()

# %%
np.sqrt(mean_squared_error(df_dem_vrate['dem_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.111)

# %%
mean_absolute_error(df_dem_vrate['dem_votes_per'], y_hat)
# Out:
# 0.08407420356213449

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_dem_vrate.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# #### Republican Voting Participation Rate

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'voter_participation',
            y = 'rep_votes_per',
            color='red',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Voting Participation Rate (%)', fontsize=16)
plt.ylabel('Percentage of Democratic Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_rep_vrate = df.dropna(subset=['voter_participation'])

# %%
model_rep_vrate = smf.ols(formula='rep_votes_per ~ voter_participation', data=df_rep_vrate).fit()

# %%
print(model_rep_vrate.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     37.62
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           2.30e-09
# Time:                        16:31:09   Log-Likelihood:                 280.21
# No. Observations:                 357   AIC:                            -556.4
# Df Residuals:                     355   BIC:                            -548.7
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.8806      0.064     13.838      0.000       0.755       1.006
# voter_participation    -0.6057      0.099     -6.133      0.000      -0.800      -0.411
# ==============================================================================
# Omnibus:                       41.227   Durbin-Watson:                   1.735
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.357
# Skew:                          -0.800   Prob(JB):                     5.79e-13
# Kurtosis:                       4.109   Cond. No.                         23.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_rep_vrate.predict()

# %%
np.sqrt(mean_squared_error(df_rep_vrate['rep_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.11)

# %%
mean_absolute_error(df_rep_vrate['rep_votes_per'], y_hat)
# Out:
# 0.08509003701171323

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_dem_vrate.resid, 'ko', mec='w')
plt.axhline(0, color='r', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Republican voters', fontsize=16)
plt.ylabel('Residual percentage of Republican voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ### Voting age 18-24 Single Inputs

# %% [markdown]
# #### Democrat Voting age 18-24 Single Inputs

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'pop_18_24_per',
            y = 'dem_votes_per',
            color='blue',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Voting 18-24 Population(Total)', fontsize=16)
plt.ylabel('Percentage of Democratic Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_dem_1824 = df.dropna(subset=['pop_18_24_per'])

# %%
model_dem_1824 = smf.ols(formula='dem_votes_per ~ pop_18_24_per', data=df_dem_1824).fit()

# %%
print(model_dem_1824.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     17.93
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           2.92e-05
# Time:                        16:31:09   Log-Likelihood:                 267.78
# No. Observations:                 357   AIC:                            -531.6
# Df Residuals:                     355   BIC:                            -523.8
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.7050      0.055     12.743      0.000       0.596       0.814
# pop_18_24_per    -1.8223      0.430     -4.235      0.000      -2.669      -0.976
# ==============================================================================
# Omnibus:                       79.969   Durbin-Watson:                   1.627
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              268.884
# Skew:                           0.970   Prob(JB):                     4.10e-59
# Kurtosis:                       6.784   Cond. No.                         72.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_dem_1824.predict()

# %%
np.sqrt(mean_squared_error(df_dem_1824['dem_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.114)

# %%
mean_absolute_error(df_dem_1824['dem_votes_per'], y_hat)
# Out:
# 0.08313630369233875

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_dem_1824.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# #### Republican Voting age 18-24 Single Inputs

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'pop_18_24_per',
            y = 'rep_votes_per',
            color='red',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Voting 18-24 Population(Total)', fontsize=16)
plt.ylabel('Percentage of Republican Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_rep_1824 = df.dropna(subset=['pop_18_24_per'])

# %%
model_rep_1824 = smf.ols(formula='rep_votes_per ~ pop_18_24_per', data=df_rep_1824).fit()

# %%
print(model_rep_1824.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     22.31
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           3.34e-06
# Time:                        16:31:10   Log-Likelihood:                 273.11
# No. Observations:                 357   AIC:                            -542.2
# Df Residuals:                     355   BIC:                            -534.5
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.2361      0.055      4.331      0.000       0.129       0.343
# pop_18_24_per     2.0025      0.424      4.724      0.000       1.169       2.836
# ==============================================================================
# Omnibus:                      101.212   Durbin-Watson:                   1.800
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              305.503
# Skew:                          -1.286   Prob(JB):                     4.58e-67
# Kurtosis:                       6.731   Cond. No.                         72.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_rep_1824.predict()

# %%
np.sqrt(mean_squared_error(df_rep_1824['rep_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.113)

# %%
mean_absolute_error(df_rep_1824['rep_votes_per'], y_hat)
# Out:
# 0.08291945425360453

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_rep_1824.resid, 'ko', mec='w')
plt.axhline(0, color='r', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Republican voters', fontsize=16)
plt.ylabel('Residual percentage of Republican voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ### Voting Age 25-44 Single Inputs

# %% [markdown]
# #### Democrat Voting Age 25-44 Single Inputs

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'pop_25_44_per',
            y = 'dem_votes_per',
            color='blue',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Voting 25-44 Population(Total)', fontsize=16)
plt.ylabel('Percentage of Democrat Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_dem_2544 = df.dropna(subset=['pop_25_44_per'])

# %%
model_dem_2544 = smf.ols(formula='dem_votes_per ~ pop_25_44_per', data=df_dem_2544).fit()

# %%
print(model_dem_2544.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     8.496
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):            0.00379
# Time:                        16:31:10   Log-Likelihood:                 263.20
# No. Observations:                 357   AIC:                            -522.4
# Df Residuals:                     355   BIC:                            -514.7
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.2828      0.065      4.334      0.000       0.154       0.411
# pop_25_44_per     0.5358      0.184      2.915      0.004       0.174       0.897
# ==============================================================================
# Omnibus:                       20.767   Durbin-Watson:                   1.576
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.195
# Skew:                           0.444   Prob(JB):                     4.58e-07
# Kurtosis:                       4.084   Cond. No.                         33.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_dem_2544.predict()

# %%
np.sqrt(mean_squared_error(df_dem_2544['dem_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.116)

# %%
mean_absolute_error(df_dem_2544['dem_votes_per'], y_hat)
# Out:
# 0.09123381072651665

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_dem_2544.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %%
plt.figure(figsize=(6,6))

sns.regplot(data=df,
            x = 'pop_25_44_per',
            y = 'rep_votes_per',
            color='red',
            ci=False,
            scatter_kws={'color': 'black', 'edgecolors': 'white', 'linewidths': 1})

#Add axis labels
plt.xlabel('Voting 25-44 Population(Total)', fontsize=16)
plt.ylabel('Percentage of Republican Votes', fontsize=16)

#Increase the fontsize of the tick labels
plt.tick_params(labelsize=14)

plt.show()

# %%
df_rep_2544 = df.dropna(subset=['pop_25_44_per'])

# %%
model_rep_2544 = smf.ols(formula='rep_votes_per ~ pop_25_44_per', data=df_rep_2544).fit()

# %%
print(model_rep_2544.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     6.443
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):             0.0116
# Time:                        16:31:10   Log-Likelihood:                 265.44
# No. Observations:                 357   AIC:                            -526.9
# Df Residuals:                     355   BIC:                            -519.1
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.6558      0.065     10.114      0.000       0.528       0.783
# pop_25_44_per    -0.4637      0.183     -2.538      0.012      -0.823      -0.104
# ==============================================================================
# Omnibus:                       36.575   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.160
# Skew:                          -0.731   Prob(JB):                     2.11e-11
# Kurtosis:                       4.080   Cond. No.                         33.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_rep_2544.predict()

# %%
np.sqrt(mean_squared_error(df_rep_2544['rep_votes_per'], y_hat)).round(3)
# Out:
# np.float64(0.115)

# %%
mean_absolute_error(df_rep_2544['rep_votes_per'], y_hat)
# Out:
# 0.09109091673202382

# %%
plt.figure(figsize=(6, 6))

plt.plot(y_hat, model_rep_2544.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ## Multiple Linear Regression Model

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                357 non-null    object
#  1   year                 357 non-null    int64
#  2   total_votes          357 non-null    int64
#  3   dem_votes            357 non-null    float64
#  4   rep_votes            357 non-null    float64
#  5   unemployment_rate    357 non-null    float64
#  6   median_income        357 non-null    int64
#  7   med_age              306 non-null    float64
#  8   bach_per             357 non-null    float64
#  9   voter_participation  357 non-null    float64
#  10  voting_age_pop       357 non-null    float64
#  11  Population 18-24     357 non-null    int64
#  12  Population 25-44     357 non-null    int64
#  13  Population 45-64     357 non-null    int64
#  14  Population 65+       357 non-null    int64
#  15  dem_votes_per        357 non-null    float64
#  16  rep_votes_per        357 non-null    float64
#  17  dem_win              357 non-null    bool
#  18  pop_18_24_per        357 non-null    float64
#  19  pop_25_44_per        357 non-null    float64
#  20  pop_45_64_per        357 non-null    float64
#  21  pop_65_per           357 non-null    float64
# dtypes: bool(1), float64(13), int64(7), object(1)
# memory usage: 59.0+ KB

# %%
model_dem = smf.ols(
    formula='dem_votes_per ~ unemployment_rate + median_income + med_age + bach_per + voting_age_pop + pop_18_24_per + pop_25_44_per + pop_45_64_per + pop_65_per + voter_participation',
    data=df).fit()

# %%
print(model_dem.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.426
# Method:                 Least Squares   F-statistic:                     23.61
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           1.82e-32
# Time:                        16:31:10   Log-Likelihood:                 320.39
# No. Observations:                 306   AIC:                            -618.8
# Df Residuals:                     295   BIC:                            -577.8
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            1092.0927    259.479      4.209      0.000     581.429    1602.756
# unemployment_rate       2.3915      0.333      7.174      0.000       1.735       3.047
# median_income        4.399e-06   5.02e-07      8.769      0.000    3.41e-06    5.39e-06
# med_age                -0.0109      0.005     -2.392      0.017      -0.020      -0.002
# bach_per               -0.2611      0.053     -4.943      0.000      -0.365      -0.157
# voting_age_pop       1.897e-09   1.05e-09      1.812      0.071   -1.63e-10    3.96e-09
# pop_18_24_per       -1093.0808    259.499     -4.212      0.000   -1603.785    -582.376
# pop_25_44_per       -1091.6732    259.491     -4.207      0.000   -1602.362    -580.985
# pop_45_64_per       -1091.3868    259.574     -4.205      0.000   -1602.239    -580.535
# pop_65_per          -1091.1937    259.447     -4.206      0.000   -1601.796    -580.592
# voter_participation     0.3064      0.095      3.236      0.001       0.120       0.493
# ==============================================================================
# Omnibus:                       97.874   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              330.202
# Skew:                           1.382   Prob(JB):                     1.98e-72
# Kurtosis:                       7.273   Cond. No.                     8.09e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.09e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_hat = model_dem.predict()

# %%
plt.figure(figsize=(7, 7))

plt.plot(y_hat, model_dem.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %%
model_rep = smf.ols(
    formula='rep_votes_per ~ unemployment_rate + median_income + med_age + bach_per + voting_age_pop + pop_18_24_per + pop_25_44_per + pop_45_64_per + pop_65_per + voter_participation',
    data=df).fit()

# %%
print(model_rep.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.403
# Model:                            OLS   Adj. R-squared:                  0.383
# Method:                 Least Squares   F-statistic:                     19.93
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           5.05e-28
# Time:                        16:31:10   Log-Likelihood:                 312.44
# No. Observations:                 306   AIC:                            -602.9
# Df Residuals:                     295   BIC:                            -561.9
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept           -1236.7355    266.312     -4.644      0.000   -1760.847    -712.624
# unemployment_rate      -1.7441      0.342     -5.098      0.000      -2.417      -1.071
# median_income       -4.282e-06   5.15e-07     -8.316      0.000    -5.3e-06   -3.27e-06
# med_age                 0.0056      0.005      1.188      0.236      -0.004       0.015
# bach_per                0.1320      0.054      2.434      0.016       0.025       0.239
# voting_age_pop      -1.356e-09   1.07e-09     -1.263      0.208   -3.47e-09    7.58e-10
# pop_18_24_per        1238.9558    266.333      4.652      0.000     714.803    1763.109
# pop_25_44_per        1237.2360    266.325      4.646      0.000     713.099    1761.373
# pop_45_64_per        1237.4761    266.410      4.645      0.000     713.172    1761.781
# pop_65_per           1237.1640    266.279      4.646      0.000     713.116    1761.212
# voter_participation    -0.3015      0.097     -3.103      0.002      -0.493      -0.110
# ==============================================================================
# Omnibus:                       96.504   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              282.752
# Skew:                          -1.423   Prob(JB):                     3.99e-62
# Kurtosis:                       6.752   Cond. No.                     8.09e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.09e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_hat = model_rep.predict()

# %%
plt.figure(figsize=(7, 7))

plt.plot(y_hat, model_rep.resid, 'ko', mec='w')
plt.axhline(0, color='r', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Republican voters', fontsize=16)
plt.ylabel('Residual percentage of Republican voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ### Reduced Model

# %% [markdown]
# #### Democrat

# %%
model_dem_reduced = smf.ols(
    formula='dem_votes_per ~ unemployment_rate + median_income + bach_per + pop_18_24_per + pop_65_per + voter_participation',
    data=df).fit()

# %%
print(model_dem_reduced.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.390
# Model:                            OLS   Adj. R-squared:                  0.380
# Method:                 Least Squares   F-statistic:                     37.30
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           6.48e-35
# Time:                        16:37:36   Log-Likelihood:                 347.22
# No. Observations:                 357   AIC:                            -680.4
# Df Residuals:                     350   BIC:                            -653.3
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.3634      0.108      3.365      0.001       0.151       0.576
# unemployment_rate       2.1286      0.318      6.686      0.000       1.502       2.755
# median_income        3.858e-06   4.55e-07      8.473      0.000    2.96e-06    4.75e-06
# bach_per               -0.1673      0.051     -3.264      0.001      -0.268      -0.066
# pop_18_24_per          -2.0071      0.467     -4.301      0.000      -2.925      -1.089
# pop_65_per             -0.9293      0.204     -4.566      0.000      -1.330      -0.529
# voter_participation     0.3220      0.091      3.549      0.000       0.144       0.500
# ==============================================================================
# Omnibus:                       67.480   Durbin-Watson:                   1.656
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              203.640
# Skew:                           0.848   Prob(JB):                     6.03e-45
# Kurtosis:                       6.289   Cond. No.                     7.88e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.88e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_hat = model_dem_reduced.predict()

# %%
plt.figure(figsize=(7, 7))

plt.plot(y_hat, model_dem_reduced.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Democrat voters', fontsize=16)
plt.ylabel('Residual percentage of Democrat voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %%
mean_absolute_error(df.loc[model_dem.fittedvalues.index, 'dem_votes_per'], model_dem_reduced.predict(df.loc[model_dem.fittedvalues.index]))
# Out:
# 0.06342573086216792

# %%
mae_full = mean_absolute_error(df.loc[model_dem.fittedvalues.index, 'dem_votes_per'], model_dem.fittedvalues)
mae_reduced = mean_absolute_error(df.loc[model_dem_reduced.fittedvalues.index, 'dem_votes_per'], model_dem_reduced.fittedvalues)

r2_full = model_dem.rsquared
r2_reduced = model_dem_reduced.rsquared

pd.DataFrame({'Mean Absolute Error': [mae_full, mae_reduced],
              'R-squared': [r2_full, r2_reduced]},
             index=['full model', 'reduced model']).round(4)
# Out:
#                Mean Absolute Error  R-squared
# full model                  0.0588     0.4446
# reduced model               0.0649     0.3900

# %% [markdown]
# #### Republican

# %%
model_rep_reduced = smf.ols(
    formula='rep_votes_per ~ unemployment_rate + median_income + pop_18_24_per + pop_65_per + voter_participation',
    data=df).fit()

# %%
print(model_rep_reduced.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.324
# Model:                            OLS   Adj. R-squared:                  0.314
# Method:                 Least Squares   F-statistic:                     33.59
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           5.23e-28
# Time:                        16:38:30   Log-Likelihood:                 332.03
# No. Observations:                 357   AIC:                            -652.1
# Df Residuals:                     351   BIC:                            -628.8
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.5720      0.111      5.147      0.000       0.353       0.791
# unemployment_rate      -1.0238      0.285     -3.588      0.000      -1.585      -0.463
# median_income        -3.55e-06   4.43e-07     -8.005      0.000   -4.42e-06   -2.68e-06
# pop_18_24_per           2.0561      0.482      4.270      0.000       1.109       3.003
# pop_65_per              0.8755      0.199      4.391      0.000       0.483       1.268
# voter_participation    -0.2980      0.094     -3.166      0.002      -0.483      -0.113
# ==============================================================================
# Omnibus:                       99.283   Durbin-Watson:                   1.792
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              265.745
# Skew:                          -1.312   Prob(JB):                     1.97e-58
# Kurtosis:                       6.314   Cond. No.                     7.65e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.65e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
plt.figure(figsize=(7, 7))

plt.plot(y_hat, model_rep_reduced.resid, 'ko', mec='w')
plt.axhline(0, color='b', linestyle='dashed', lw=2)

plt.xlabel('Predicted percentage of Republican voters', fontsize=16)
plt.ylabel('Residual percentage of Republican voters', fontsize=16)

plt.tick_params(labelsize=14)

plt.tight_layout()
plt.show()

# %%
mean_absolute_error(df.loc[model_rep.fittedvalues.index, 'rep_votes_per'], model_rep_reduced.predict(df.loc[model_rep.fittedvalues.index]))
# Out:
# 0.06602970431256457

# %%
mae_full = mean_absolute_error(df.loc[model_rep.fittedvalues.index, 'rep_votes_per'], model_rep.fittedvalues)
mae_reduced = mean_absolute_error(df.loc[model_rep_reduced.fittedvalues.index, 'rep_votes_per'], model_rep_reduced.fittedvalues)

r2_full = model_rep.rsquared
r2_reduced = model_rep_reduced.rsquared

pd.DataFrame({'Mean Absolute Error': [mae_full, mae_reduced],
              'R-squared': [r2_full, r2_reduced]},
             index=['full model', 'reduced model']).round(4)
# Out:
#                Mean Absolute Error  R-squared
# full model                  0.0618     0.4032
# reduced model               0.0685     0.3236

# %% [markdown]
# ### Scaling

# %%
predictor_variables = ['unemployment_rate', 'median_income', 'bach_per', 'pop_65_per', 'voter_participation', 'pop_18_24_per']

# %%
scaled_columns = [var + '_normalized' for var in predictor_variables]
print(scaled_columns)
# Out:
# ['unemployment_rate_normalized', 'median_income_normalized', 'bach_per_normalized', 'pop_65_per_normalized', 'voter_participation_normalized', 'pop_18_24_per_normalized']

# %%
df_scaled = df.dropna(subset=predictor_variables).copy()
scaler = StandardScaler().fit(df_scaled[predictor_variables])

# %%
df_scaled[scaled_columns] = scaler.transform(df_scaled[predictor_variables])

# %%
df_scaled[scaled_columns].agg(['mean','std']).round(3)
# Out:
#       unemployment_rate_normalized  median_income_normalized  \
# mean                        -0.000                     0.000
# std                          1.001                     1.001
#
#       bach_per_normalized  pop_65_per_normalized  \
# mean                0.000                  0.000
# std                 1.001                  1.001
#
#       voter_participation_normalized  pop_18_24_per_normalized
# mean                          -0.000                     0.000
# std                            1.001                     1.001

# %%
formula_norm = 'dem_votes_per ~ ' + ' + '.join(scaled_columns)
model_normalized = smf.ols(formula=formula_norm, data=df_scaled).fit()

# %%
print(model_normalized.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          dem_votes_per   R-squared:                       0.390
# Model:                            OLS   Adj. R-squared:                  0.380
# Method:                 Least Squares   F-statistic:                     37.30
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           6.48e-35
# Time:                        16:31:11   Log-Likelihood:                 347.22
# No. Observations:                 357   AIC:                            -680.4
# Df Residuals:                     350   BIC:                            -653.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.4722      0.005     96.552      0.000       0.463       0.482
# unemployment_rate_normalized       0.0401      0.006      6.686      0.000       0.028       0.052
# median_income_normalized           0.0507      0.006      8.473      0.000       0.039       0.062
# bach_per_normalized               -0.0200      0.006     -3.264      0.001      -0.032      -0.008
# pop_65_per_normalized             -0.0307      0.007     -4.566      0.000      -0.044      -0.018
# voter_participation_normalized     0.0191      0.005      3.549      0.000       0.009       0.030
# pop_18_24_per_normalized          -0.0283      0.007     -4.301      0.000      -0.041      -0.015
# ==============================================================================
# Omnibus:                       67.480   Durbin-Watson:                   1.656
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              203.640
# Skew:                           0.848   Prob(JB):                     6.03e-45
# Kurtosis:                       6.289   Cond. No.                         2.91
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mae_normalized = mean_absolute_error(df_scaled.loc[model_normalized.fittedvalues.index, 'dem_votes_per'], model_normalized.fittedvalues)
mae_reduced = mean_absolute_error(df.loc[model_dem_reduced.fittedvalues.index, 'dem_votes_per'], model_dem_reduced.fittedvalues)

r2_normalized = model_normalized.rsquared
r2_reduced = model_dem_reduced.rsquared

pd.DataFrame({'Mean Absolute Error': [mae_normalized, mae_reduced],
              'R-squared': [r2_normalized, r2_reduced]},
             index=['normalized model', 'reduced model']).round(4)
# Out:
#                   Mean Absolute Error  R-squared
# normalized model               0.0649     0.3900
# reduced model                  0.0633     0.4124

# %%
predictor_variables = ['unemployment_rate', 'median_income', 'pop_65_per', 'voter_participation', 'pop_18_24_per']

# %%
scaled_columns = [var + '_normalized' for var in predictor_variables]
print(scaled_columns)
# Out:
# ['unemployment_rate_normalized', 'median_income_normalized', 'pop_65_per_normalized', 'voter_participation_normalized', 'pop_18_24_per_normalized']

# %%
df_scaled = df.dropna(subset=predictor_variables).copy()
scaler = StandardScaler().fit(df_scaled[predictor_variables])

# %%
df_scaled[scaled_columns] = scaler.transform(df_scaled[predictor_variables])

# %%
df_scaled[scaled_columns].agg(['mean','std']).round(3)
# Out:
#       unemployment_rate_normalized  median_income_normalized  \
# mean                        -0.000                     0.000
# std                          1.001                     1.001
#
#       pop_65_per_normalized  voter_participation_normalized  \
# mean                  0.000                          -0.000
# std                   1.001                           1.001
#
#       pop_18_24_per_normalized
# mean                     0.000
# std                      1.001

# %%
formula_norm = 'rep_votes_per ~ ' + ' + '.join(scaled_columns)
model_normalized = smf.ols(formula=formula_norm, data=df_scaled).fit()

# %%
print(model_normalized.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          rep_votes_per   R-squared:                       0.324
# Model:                            OLS   Adj. R-squared:                  0.314
# Method:                 Least Squares   F-statistic:                     33.59
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           5.23e-28
# Time:                        16:37:05   Log-Likelihood:                 332.03
# No. Observations:                 357   AIC:                            -652.1
# Df Residuals:                     351   BIC:                            -628.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.4920      0.005     96.548      0.000       0.482       0.502
# unemployment_rate_normalized      -0.0193      0.005     -3.588      0.000      -0.030      -0.009
# median_income_normalized          -0.0466      0.006     -8.005      0.000      -0.058      -0.035
# pop_65_per_normalized              0.0290      0.007      4.391      0.000       0.016       0.042
# voter_participation_normalized    -0.0177      0.006     -3.166      0.002      -0.029      -0.007
# pop_18_24_per_normalized           0.0290      0.007      4.270      0.000       0.016       0.042
# ==============================================================================
# Omnibus:                       99.283   Durbin-Watson:                   1.792
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              265.745
# Skew:                          -1.312   Prob(JB):                     1.97e-58
# Kurtosis:                       6.314   Cond. No.                         2.39
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mae_normalized = mean_absolute_error(df_scaled.loc[model_normalized.fittedvalues.index, 'rep_votes_per'], model_normalized.fittedvalues)
mae_reduced = mean_absolute_error(df.loc[model_dem_reduced.fittedvalues.index, 'rep_votes_per'], model_dem_reduced.fittedvalues)

r2_normalized = model_normalized.rsquared
r2_reduced = model_dem_reduced.rsquared

pd.DataFrame({'Mean Absolute Error': [mae_normalized, mae_reduced],
              'R-squared': [r2_normalized, r2_reduced]},
             index=['normalized model', 'reduced model']).round(4)
# Out:
#                   Mean Absolute Error  R-squared
# normalized model               0.0668     0.3610
# reduced model                  0.1397     0.4124
